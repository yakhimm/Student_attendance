# %%
import pandas as pd
import numpy as np
import Convert_CSV as CSV

from os import walk

# %%
path_train = '../dataset/train/'

# %%
def replace_pins(col):
    col.replace('pins_', '')

new_path = next(walk(path_train), (None, None, []))[1]
for i in range(len(new_path)):
    new_path[i] = new_path[i].replace('pins_', '')
new_path = np.insert(new_path, 0, 'Unknown')
names = pd.DataFrame(new_path, columns= ['Name'])
names.to_csv('name.csv')

# %%
CSV.img_to_csv(path_train, 'train.csv')
# Out:
# ../dataset/train/pins_Adriana Lima/Adriana Lima0_0.jpg
# ...
# 1/1 [==============================] - 0s 201ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima101_3.jpg
# ...
# 1/1 [==============================] - 0s 173ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima102_4.jpg
# ...
# 1/1 [==============================] - 0s 156ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima103_5.jpg
# ...
# 1/1 [==============================] - 0s 155ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima104_6.jpg
# ...
# 1/1 [==============================] - 0s 164ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima105_7.jpg
# ...
# 1/1 [==============================] - 0s 171ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima106_8.jpg
# ...
# 1/1 [==============================] - 0s 191ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima108_10.jpg
# ...
# 1/1 [==============================] - 0s 186ms/step
#
# ../dataset/train/pins_Adriana Lima/Adriana Lima109_11.jpg
# ...
